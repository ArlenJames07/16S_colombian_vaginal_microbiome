# %% [markdown]
# ## Import libraries

# %%
from pathlib import Path
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

from scipy.cluster.hierarchy import linkage, fcluster, leaves_list
from scipy.spatial.distance import pdist

# %%
# Detect repository root whether notebook is opened from root or notebooks/
CURRENT_DIR = Path.cwd()

if CURRENT_DIR.name == "notebooks":
    REPO_ROOT = CURRENT_DIR.parent
else:
    REPO_ROOT = CURRENT_DIR

folder_results = REPO_ROOT / "results"
metadata_file = REPO_ROOT / "data/input_files/manifest_curated_nugent.tsv"

speciateit_folder = folder_results / "speciateit_refinement"

species_rel_file = speciateit_folder / "species_relative_abundance_samples_by_species.csv"
merged_feature_table_file = speciateit_folder / "merged_feature_table_speciateIT.csv"

cst_output_folder = folder_results / "cst_assignment"
cst_output_folder.mkdir(parents=True, exist_ok=True)

print("Repository root:", REPO_ROOT)
print("Species table:", species_rel_file)
print("Metadata file:", metadata_file)
print("CST output folder:", cst_output_folder)
# Out:
# Repository root: /home/rare/arlen/16S_colombian_vaginal_microbiome/scripts
# Species table: /home/rare/arlen/16S_colombian_vaginal_microbiome/scripts/results/speciateit_refinement/species_relative_abundance_samples_by_species.csv
# Metadata file: /home/rare/arlen/16S_colombian_vaginal_microbiome/scripts/data/input_files/manifest_curated_nugent.tsv
# CST output folder: /home/rare/arlen/16S_colombian_vaginal_microbiome/scripts/results/cst_assignment
